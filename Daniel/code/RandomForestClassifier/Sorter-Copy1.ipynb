# %%
import pandas as pd
import matplotlib
from sklearn import preprocessing
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\dakar\Desktop\NFL\NFL.csv', low_memory=False)

# %%
#filter columns
nedf = df[['posteam','qtr','down','game_seconds_remaining', 'yardline_100', 'down', 'ydstogo', 'play_type', 'pass_length', 'pass_location', 'run_location']]

# %%
nedf.dropna()
# Out:
#        posteam  qtr  down  game_seconds_remaining  yardline_100  down  \
# 48917      STL    1   2.0                  3574.0          73.0   2.0
# 53483      DEN    2   1.0                  2544.0          22.0   1.0
# 56862      ATL    4   1.0                   698.0          52.0   1.0
# 153643     STL    3   2.0                  1608.0          76.0   2.0
#
#         ydstogo play_type pass_length pass_location run_location
# 48917         8       run       short         right        right
# 53483        10       run       short          left         left
# 56862        10       run       short        middle       middle
# 153643        6       run       short          left         left

# %%
nedf
# Out:
#        posteam  qtr  down  game_seconds_remaining  yardline_100  down  \
# 0          PIT    1   NaN                  3600.0          30.0   NaN
# 1          PIT    1   1.0                  3593.0          58.0   1.0
# 2          PIT    1   2.0                  3556.0          53.0   2.0
# 3          PIT    1   3.0                  3515.0          56.0   3.0
# 4          PIT    1   4.0                  3507.0          56.0   4.0
# ...        ...  ...   ...                     ...           ...   ...
# 449366     CAR    4   2.0                    63.0          66.0   2.0
# 449367     CAR    4   3.0                    58.0          66.0   3.0
# 449368     CAR    4   4.0                    38.0          61.0   4.0
# 449369      NO    4   1.0                    35.0          39.0   1.0
# 449370     NaN    4   NaN                     0.0           NaN   NaN
#
#         ydstogo play_type pass_length pass_location run_location
# ...
