# %%
import pandas as pd
import matplotlib
from sklearn import preprocessing
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\dakar\Desktop\NFL\NFL.csv', low_memory=False)

# %%
#filter columns
nedf = df[['posteam','qtr','score_differential','game_seconds_remaining', 'yardline_100', 'down', 'ydstogo', 'play_type', 'pass_length', 'pass_location', 'run_location']]

# %%
nedf
# Out:
#        posteam  qtr  score_differential  game_seconds_remaining  yardline_100  \
# 0          PIT    1                 NaN                  3600.0          30.0
# 1          PIT    1                 0.0                  3593.0          58.0
# 2          PIT    1                 0.0                  3556.0          53.0
# 3          PIT    1                 0.0                  3515.0          56.0
# 4          PIT    1                 0.0                  3507.0          56.0
# ...        ...  ...                 ...                     ...           ...
# 449366     CAR    4                -5.0                    63.0          66.0
# 449367     CAR    4                -5.0                    58.0          66.0
# 449368     CAR    4                -5.0                    38.0          61.0
# 449369      NO    4                 5.0                    35.0          39.0
# 449370     NaN    4                 NaN                     0.0           NaN
#
# ...

# %%
nedf.to_csv (r'C:\Users\dakar\Desktop\Finalpj\raw2.csv', index = False, header=True)
